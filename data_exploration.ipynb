# %%
import collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import glob as glob
import nltk
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer
import collections

# %%
from get_industries_func import extract_keyword_count, get_industries, new_categories
from ngrams import ngrams
from ngrams_generator import ngrams_generator
from pre_process import pre_process
from wordcloud_plot import wordcloud_plot

# %%
# nltk.download('stopwords')

# %% [markdown]
# ## 1.Data EDA

# %%
raw_data = pd.read_csv('data_scientist_united_states_job_postings_jobspikr.csv')

# %%
raw_data.head()
# Out:
#              crawl_timestamp  \
# 0  2019-02-06 05:26:22 +0000
# 1  2019-02-06 05:33:41 +0000
# 2  2019-02-06 05:33:35 +0000
# 3  2019-02-06 05:33:42 +0000
# 4  2019-02-06 05:48:23 +0000
#
#                                                  url  \
# 0  https://www.indeed.com/viewjob?jk=fd83355c2b23...
# 1  https://www.dice.com/jobs/detail/Data-Scientis...
# 2  https://www.dice.com/jobs/detail/Data-Scientis...
# 3  https://www.indeed.com/viewjob?jk=841edd86ead2...
# 4  https://job-openings.monster.com/senior-data-s...
#
#                                            job_title            category  \
# 0                        Enterprise Data Scientist I  Accounting/Finance
# 1                                     Data Scientist                 NaN
# 2                                     Data Scientist                 NaN
# 3  Data Scientist, Aladdin Wealth Tech, Associate...  Accounting/Finance
# 4                              Senior Data Scientist             biotech
#
#                            company_name            city  \
# 0               Farmers Insurance Group  Woodland Hills
# 1                        Luxoft USA Inc      Middletown
# 2  Cincinnati Bell Technology Solutions        New York
# 3                             BlackRock        New York
# 4                           CyberCoders       Charlotte
#
#                      state country   inferred_city  inferred_state  \
# 0                       CA     Usa  Woodland hills      California
# 1                       NJ     Usa      Middletown      New jersey
# 2                       NY     Usa        New york        New york
# 3  NY 10055 (Midtown area)     Usa        New york        New york
# 4                       NC     Usa       Charlotte  North carolina
#
#           ...                                             job_description  \
# 0         ...           Read what people are saying about working here...
# 1         ...           We have an immediate opening for a Sharp Data ...
# 2         ...           Candidates should have the following backgroun...
# 3         ...           Read what people are saying about working here...
# 4         ...           We are seeking an extraordinary Data Scientist...
#
#     job_type salary_offered job_board  geo            cursor contact_email  \
# 0  Undefined            NaN    indeed  usa  1549432819114777           NaN
# 1  Undefined            NaN      dice  usa  1549432819122106           NaN
# 2  Full Time            NaN      dice  usa  1549432819236156           NaN
# 3  Undefined            NaN    indeed  usa  1549432819259473           NaN
# 4  Full Time            NaN   monster  usa  1549436429015957           NaN
#
#    contact_phone_number                           uniq_id html_job_description
# 0                   NaN  3b6c6acfcba6135a31c83bd7ea493b18                  NaN
# 1                   NaN  741727428839ae7ada852eebef29b0fe                  NaN
# 2                   NaN  cdc9ef9a1de327ccdc19cc0d07dbbb37                  NaN
# 3                   NaN  1c8541cd2c2c924f9391c7d3f526f64e                  NaN
# 4                   NaN  445652a560a5441060857853cf267470                  NaN
#
# [5 rows x 22 columns]

# %%
data = raw_data.drop(columns=['url', 'inferred_city', 'inferred_state', 'job_type', 'salary_offered',
                              'job_board', 'geo', 'contact_email','contact_phone_number', 'html_job_description'])

# %%
data.shape
# Out:
# (10000, 12)

# %%
# map categories to ten categories using our defined functions
new_cat = new_categories(data)
data['category'] = new_cat['category']

# %%
data.head()
# Out:
#              crawl_timestamp  \
# 0  2019-02-06 05:26:22 +0000
# 1  2019-02-06 05:33:41 +0000
# 2  2019-02-06 05:33:35 +0000
# 3  2019-02-06 05:33:42 +0000
# 4  2019-02-06 05:48:23 +0000
#
#                                            job_title  \
# 0                        Enterprise Data Scientist I
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3  Data Scientist, Aladdin Wealth Tech, Associate...
# 4                              Senior Data Scientist
#
#                      category                          company_name  \
# 0          financial services               Farmers Insurance Group
# 1                       other                        Luxoft USA Inc
# 2                       other  Cincinnati Bell Technology Solutions
# 3          financial services                             BlackRock
# 4  life sciences & healthcare                           CyberCoders
#
#              city                    state country inferred_country  \
# 0  Woodland Hills                       CA     Usa              Usa
# 1      Middletown                       NJ     Usa              Usa
# 2        New York                       NY     Usa              Usa
# 3        New York  NY 10055 (Midtown area)     Usa              Usa
# 4       Charlotte                       NC     Usa              Usa
#
#     post_date                                    job_description  \
# 0  2019-02-06  Read what people are saying about working here...
# 1  2019-02-05  We have an immediate opening for a Sharp Data ...
# 2  2019-02-05  Candidates should have the following backgroun...
# 3  2019-02-06  Read what people are saying about working here...
# 4  2019-02-05  We are seeking an extraordinary Data Scientist...
#
#              cursor                           uniq_id
# 0  1549432819114777  3b6c6acfcba6135a31c83bd7ea493b18
# 1  1549432819122106  741727428839ae7ada852eebef29b0fe
# 2  1549432819236156  cdc9ef9a1de327ccdc19cc0d07dbbb37
# 3  1549432819259473  1c8541cd2c2c924f9391c7d3f526f64e
# 4  1549436429015957  445652a560a5441060857853cf267470

# %% [markdown]
# ### Data Exploration

# %%
# drop NA rows
data_com = data[pd.notnull(data['company_name'])]

# %%
num_company=data_com['company_name'].nunique()
print('Toatl number of firms',num_company)

#finding highest number of vacancy in a company
company=data_com.groupby(['company_name'])['job_title'].count()
company=company.reset_index()
company=company.sort_values(['job_title'],ascending=False)
print('Top 25 firms with most vacancies',company.head(25))

fig, ax = plt.subplots(figsize = (10,6))
ax=sns.barplot(x="job_title", y="company_name", data=company.head(25))    
# ax.set_xticklabels(company['company_name'])  
ax.set_xlabel('Number of jobs',fontsize=12, color='red')
ax.set_ylabel('Companies with most job positions',fontsize=12,color='red')
# Out:
# Toatl number of firms 4137
# Top 25 firms with most vacancies                                   company_name  job_title
# 1350                               CyberCoders        628
# 2197                           Jefferson Frank        259
# 2667              Nigel Frank International US         88
# 552                        Booz Allen Hamilton         77
# 3482                                   Taboola         77
# 331                               Apex Systems         72
# 2285                         Kforce Technology         71
# 3587                           The Judge Group         67
# 3305  Social Science Research Solutions (SSRS)         67
# 3142                    Robert Half Technology         63
# 3464                           TEKsystems, Inc         61
# 1616                                  Facebook         56
# 1984                                       IBM         52
# 2238                                      KPMG         49
# 2339                                    Leidos         49
# 3071                               Realtor.com         45
# 338                                      Apple         45
# 261                  Amazon.com Services, Inc.         43
# 2684                          Northrop Grumman         43
# 872                                  Collabera         41
# 3772                        UnitedHealth Group         41
# 2522                                 Microsoft         38
# 3898                                   Verizon         36
# 1604                                   Experis         36
# 3968                                   Walmart         34
# Text(0, 0.5, 'Companies with most job positions')

# %%
data_cat = data[pd.notnull(data['category'])]

# %%
# Finding total number of unique categories
total_cat=data_cat['category'].nunique()
print('Toatl number of categoris across all the firms',total_cat)
# most popular industries
indus=data_cat.groupby(['category'])['company_name'].count()
indus=indus.reset_index()
indus=indus.sort_values(['company_name'],ascending=False)   
print('Top 30 most popular categories',indus)

fig,ax=plt.subplots(figsize=(12,6))
ax=sns.barplot(x="company_name", y="category", data=indus.head(30))    
# ax.set_xticklabels(indus['category'],rotation=90)
ax.set_xlabel('Number of jobs',fontsize=12,color='red')
ax.set_ylabel('Most popular industries',fontsize=12,color='red')
# Out:
# Toatl number of categoris across all the firms 14
# Top 30 most popular categories                                              category  company_name
# 4                                  financial services          1533
# 12                                  sales & marketing          1348
# 9            management, administration, & consulting          1242
# 5                      government services & security           969
# 3                            engineering & technology           900
# 13  transportation, manufacturing, and operations ...           897
# 8                          life sciences & healthcare           895
# 10                                              other           886
# 6                                      human services           763
# 7                                       legal affairs           467
# 2                                           education            70
# 0                                         agriculture            15
# 1                                arts & entertainment             9
# 11                         real estate & construction             5
# Text(0, 0.5, 'Most popular industries')

# %% [markdown]
# ### Project Cities on U.S. Map

# %% [markdown]
# ## 2. Word Preprocessing and NLP

# %% [markdown]
# ### Data Cleasing

# %%
mapper = {'apache spark':'spark', 'math':'mathematics', 'applied mathematics':'mathematics', 
          'nlp':'natural language processing', 'advanced analytics':'analytics', 'applied math':'mathematics',
          'aws':'amazon web services',  'data analytics': 'analytics', 'sql server':'sql' , 
          'git': 'github', 'cs':'computer science', 'ml': 'machine learning', 'big': 'big data',
          'sql experience': 'sql', 'dl': 'deep learning', 'business analytics': 'analytics',
          'powerbi': 'power bi', 'r experience': 'r',
          'office':'microsoft office', 'python experience':'python', 'applied statistics': 'statistics',
          'ms office':'microsoft office', 'azure':'microsoft azure', 'predictive analytics': 'analytics'}

# %%
stop_words = nltk.corpus.stopwords.words('english')
newStopWords = ['equal', 'opportunity','employer','race', 'color',
                'religion', 'sexual', 'orientation', 'gender', 
                'gender','identity', 'employment', 'without',
                'regard','color','religion', 'sex', 'summary', 'location', 
                'employment', 'consideration', 'veteran','sex',
                'nation','origin','protected','applicants','receive',
                'national', 'disability', 'read','people','saying','about','what','working',
                'full','time','employee','status', 'posted', 'today', 'scientist', 'science','data',
               'using','work','related','field']
stop_words.extend(newStopWords)

# %%
data = data[pd.notnull(data['job_description'])]
data.job_description = data.job_description.apply(lambda x:pre_process(x,stop_words,mapper))

# %%
data.job_description.head(5)
# Out:
# 0    [farmers, join, team, diverse, professionals, ...
# 1    [immediate, opening, sharp, strong, mathematic...
# 2    [candidates, following, background, skills, ch...
# 3    [blackrock, blackrock, helps, investors, build...
# 4    [seeking, extraordinary, charlotte, join, fast...
# Name: job_description, dtype: object

# %%
data.head()
# Out:
#              crawl_timestamp  \
# 0  2019-02-06 05:26:22 +0000
# 1  2019-02-06 05:33:41 +0000
# 2  2019-02-06 05:33:35 +0000
# 3  2019-02-06 05:33:42 +0000
# 4  2019-02-06 05:48:23 +0000
#
#                                            job_title  \
# 0                        Enterprise Data Scientist I
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3  Data Scientist, Aladdin Wealth Tech, Associate...
# 4                              Senior Data Scientist
#
#                      category                          company_name  \
# 0          financial services               Farmers Insurance Group
# 1                       other                        Luxoft USA Inc
# 2                       other  Cincinnati Bell Technology Solutions
# 3          financial services                             BlackRock
# 4  life sciences & healthcare                           CyberCoders
#
#              city                    state country inferred_country  \
# 0  Woodland Hills                       CA     Usa              Usa
# 1      Middletown                       NJ     Usa              Usa
# 2        New York                       NY     Usa              Usa
# 3        New York  NY 10055 (Midtown area)     Usa              Usa
# 4       Charlotte                       NC     Usa              Usa
#
#     post_date                                    job_description  \
# 0  2019-02-06  [farmers, join, team, diverse, professionals, ...
# 1  2019-02-05  [immediate, opening, sharp, strong, mathematic...
# 2  2019-02-05  [candidates, following, background, skills, ch...
# 3  2019-02-06  [blackrock, blackrock, helps, investors, build...
# 4  2019-02-05  [seeking, extraordinary, charlotte, join, fast...
#
#              cursor                           uniq_id
# 0  1549432819114777  3b6c6acfcba6135a31c83bd7ea493b18
# 1  1549432819122106  741727428839ae7ada852eebef29b0fe
# 2  1549432819236156  cdc9ef9a1de327ccdc19cc0d07dbbb37
# 3  1549432819259473  1c8541cd2c2c924f9391c7d3f526f64e
# 4  1549436429015957  445652a560a5441060857853cf267470

# %%
descrip = data.job_description

# %%
import itertools
all_text = itertools.chain.from_iterable(descrip)
all_text = ' '.join(all_text)

# %% [markdown]
# ### Wordcloud

# %%
wordcloud_plot(all_text, stop_words, max_words=30, title='Word Cloud For Data Science Jobs')

# %% [markdown]
# ### N-grams

# %%
#barplot top phrases
# unigram
phrase, count = ngrams_generator(descrip, 1, 20, stop_words)

plt.figure(figsize=(12,8))

sns.set(style="darkgrid")
sns.set_color_codes("muted")

# Create barplot 
ax = sns.barplot(count, phrase, color="salmon", orient='h')
# Annotate every single Bar with its value, based on it's width           
for p in ax.patches:
    width = p.get_width()
    plt.text(5+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

plt.xlabel("Word Count", fontsize=12, color='red')
plt.ylabel("Unigrams", fontsize=12, color='red')
plt.title("Top 20 Unigrams for Data Science Jobs")
plt.show()
# Out:
# ['experience', 'business', 'learning', 'analytics', 'team', 'machine', 'analysis', 'skills', 'models', 'years', 'ability', 'solutions', 'statistical', 'knowledge', 'new', 'tools', 'development', 'job', 'research', 'technical']
# [59197, 33919, 27304, 21991, 21155, 20770, 20672, 19824, 16563, 16253, 15687, 15122, 14695, 13271, 12781, 12777, 12774, 12485, 12298, 12244]

# %%
# bigram
phrase, count = ngrams_generator(descrip, 2, 20, stop_words)

plt.figure(figsize=(12,8))

sns.set(style="darkgrid")
sns.set_color_codes("muted")

# Create barplot 
ax = sns.barplot(count, phrase, color="salmon", orient='h')
# Annotate every single Bar with its value, based on it's width           
for p in ax.patches:
    width = p.get_width()
    plt.text(5+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')
plt.xlabel("Word Count", fontsize=12, color='red' )
plt.ylabel("Biigrams", fontsize=12, color='red')
plt.title("Top 20 Bigrams for Data Science Jobs")
plt.show()
# Out:
# ['machine learning', 'years experience', 'deep learning', 'communication skills', 'bachelor degree', 'advanced analytics', 'master degree', 'problem solving', 'statistical analysis', 'business problems', 'predictive modeling', 'artificial intelligence', 'learning techniques', 'natural language', 'operations research', 'mathematics statistics', 'predictive models', 'language processing', 'decision making', 'learning models']
# [20329, 8328, 3438, 3437, 3133, 2871, 2734, 2671, 2620, 2578, 2316, 2286, 2120, 2057, 2049, 1917, 1898, 1853, 1842, 1817]

# %%
# trigram
phrase, count = ngrams_generator(descrip, 3, 20, stop_words)

plt.figure(figsize=(12,8))

sns.set(style="darkgrid")
sns.set_color_codes("muted")

# Create barplot 
ax = sns.barplot(count, phrase, color="salmon", orient='h')
# Annotate every single Bar with its value, based on it's width           
for p in ax.patches:
    width = p.get_width()
    plt.text(5+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')
plt.xlabel("Word Count", fontsize=12, color='red')
plt.ylabel("tigrams", fontsize=12, color='red')
plt.title("Top 20 Trigrams for Data Science Jobs")
plt.show()
# Out:
# ['machine learning techniques', 'natural language processing', 'machine learning algorithms', 'machine learning models', 'experience machine learning', 'problem solving skills', 'years relevant experience', 'written communication skills', 'statistics machine learning', 'machine learning statistical', 'cross functional teams', 'learning deep learning', 'statistical machine learning', 'machine learning deep', 'federal state local', 'learning artificial intelligence', 'medical dental vision', 'written verbal communication', 'communication skills ability', 'modeling machine learning']
# [1873, 1837, 1512, 1502, 1174, 1142, 1049, 874, 827, 805, 790, 778, 756, 752, 744, 699, 695, 694, 689, 673]

# %% [markdown]
# ## Future Work...
# ### We will try using TF-IDF to vectorize the descriptions, and use machine learning models to see if we can classify the jobs of different industries based on descriptions.
